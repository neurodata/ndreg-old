# %%
# %matplotlib inline

# %% [markdown]
# # Volumetric Registration and Analysis
# In this tutorial we align a CLARITY brain to the Allen Reference Atlas (ARA).  Thus the ARA is our _reference_ image, it consists of image data stored in the default "average" channel and corresponding annotations stored in a separate "annotation" channel.  We begin by importing the relevant modules

# %%
from ndreg import *
import matplotlib
import ndio.remote.neurodata as neurodata

# %% [markdown]
# ## Downloading Atlas
# First we'll download the atlas image

# %%
refToken = "ara_ccf3"
refImg = imgDownload(refToken)

# %% [markdown]
# Next we'll visuaize the image.  To ensure that the visuization is has good contrast we'll only show intensity values below the 99th percentile.

# %%
refThreshold = imgPercentile(refImg, 0.99)
print(refThreshold)
# Out:
# 269.129411765

# %% [markdown]
# When given an image volume *imgShow* displays it as a set of evenly spaced z-slices (1st column), y-slices (2nd column) and x slices (3rd column).

# %%
imgShow(refImg, vmax=refThreshold)

# %% [markdown]
# ## Downloading CLARITY brain
# Our *input* image will be the CLARITY brain.  At full resolution, CLARITY brains can be 1 Terabyte in size, far to large to be downloaded to a personal computer.  Thus *ndstore* stores the brains at multiple resolutions. Resolution 0 is always the highest resolution each subsequent resoltion takes up 1/4th (under slice scaling) or 1/8th (under isotropic scaling) as many bytes as the previous resoltion.  Lets look at the resolution of the ARA

# %%
print(refImg.GetSpacing())
# Out:
# (0.01, 0.01, 0.01)

# %% [markdown]
# It is 0.01 X 0.01 X 0.01 mm (10 x 10 x 10 um).  Therefore we'll want to download the CLARITY brain at a simmilar resolution. We can use ndio's get_metadata method to see a list of available resoltions.

# %%
inToken = "155DLS_tail"
inChannel = "ch1"
nd = neurodata()
resolutionDict = nd.get_metadata(inToken)['dataset']['voxelres']
resolutionList = map(int,resolutionDict.keys())
resolutionList.sort()
for resolution in resolutionList:
    print(resolution, resolutionDict[str(resolution)])
# Out:
# (0, [585.0, 585.0, 5000.0])
# (1, [1170.0, 1170.0, 5000.0])
# (2, [2340.0, 2340.0, 5000.0])
# (3, [4680.0, 4680.0, 5000.0])
# (4, [9360.0, 9360.0, 5000.0])
# (5, [18720.0, 18720.0, 5000.0])
# (6, [37440.0, 37440.0, 5000.0])
# (7, [74880.0, 74880.0, 5000.0])
# (8, [149760.0, 149760.0, 5000.0])
# (9, [299520.0, 299520.0, 5000.0])
# (10, [599040.0, 599040.0, 5000.0])

# %% [markdown]
# Resolution 4 is 9.36 x 9.36 x 5 um is the closest to what we want.  So we'll download the CLARITY image at that resolution.  Depending on your internet connection downloading may take several minutes.

# %%
inResolution=4
inImg = imgDownload(inToken, inChannel, resolution=inResolution)

# %% [markdown]
# Once again we'll only use intensity values below the 99th percentile in the visualization.

# %% [markdown]
# ## Reorienting CLARITY image
# You may have noticed that the CLARITY brain is not oriented in the same way as the atlas.  Let's look at the atlas.

# %%
inThreshold = imgPercentile(inImg, 0.99)
imgShow(inImg, vmax=inThreshold)

# %%
imgShow(refImg, vmax=refThreshold)

# %% [markdown]
# By examining the the z slices in the first column its clear that the x-axis goes from **R**ight to Left side of the brain. The y-axis varies from **S**uperior to Inferior and the z-axis goes from **A**nterior to posterior.  Thus it is in **RSA** orientation.  Looking at the the CLARITY brain...

# %%
imgShow(inImg, vmax=inThreshold)

# %% [markdown]
# ...we see that the x-axis goes from **I**nferior to Superior, the y-axis goes from **P**osterior to Anterior and the Z axis goes from **L**eft to Right.  Thus it's in **IPL** orientation.  Therefore we reorient the CLARITY image from **IPL** to **RSA**

# %%
inOrient = "PLI"
refOrient = "RSA"
inImg = imgReorient(inImg, inOrient, refOrient)
imgShow(inImg, vmax=inThreshold)

# %% [markdown]
# Compare the above to the Atlas.  The slices should now correspond with the atlas even though in this case we only have half of a CLARITY brain. Let's make a copy of the reorianted image size and spacing because we'll need it later.

# %%
inImgSize_reorient = inImg.GetSize()
inImgSpacing_reorient= inImg.GetSpacing()

# %% [markdown]
# ## Resampling CLARITY image
# Notice how the CLARITY brain's resolution is higher than the ARA image that we want to align it to.

# %%
print(inImg.GetSpacing())
# Out:
# (0.005, 0.00936, 0.00936)

# %%
print(refImg.GetSpacing())
# Out:
# (0.01, 0.01, 0.01)

# %% [markdown]
# Since we are aliging the CLARITY image to a lower resolution atlas we resample it to the resolution atlas.

# %%
inImg = imgResample(inImg, spacing=refImg.GetSpacing())
imgShow(inImg, vmax=inThreshold)

# %% [markdown]
# ## Thresholding CLARITY image
# Lets plot the histogram of the CLARITY image

# %%
(values, bins) = np.histogram(sitk.GetArrayFromImage(inImg), bins=100, range=(0,500))
plt.plot(bins[:-1], values)

# %% [markdown]
# Notice the huge spike at 100.  This occurs because the intensity of the background is about 100. Idealy we want a black background with an intensity of 0.  Therefore we'll threhold the image below 100 and then subtract 100 from the image.  Notice how we've recalculate the visualization threshold "inThreshold" since we've changed the intensity of the input image.

# %%
lowerThreshold = 100
upperThreshold = sitk.GetArrayFromImage(inImg).max()+1

inImg = sitk.Threshold(inImg,lowerThreshold,upperThreshold,lowerThreshold) - lowerThreshold
inThreshold -= lowerThreshold

imgShow(inImg, vmax=inThreshold)

# %% [markdown]
# Here's a histogram of the result

# %%
(values, bins) = np.histogram(sitk.GetArrayFromImage(inImg), bins=100, range=(0,500))
plt.plot(bins[:-1], values)

# %% [markdown]
# ## Generating CLARITY mask
# CLARITY brains contain really brignt fluorescent spots in the cerebral cortex and thalamus which can interfer with the registration.

# %%
imgShow(inImg, vmax=inThreshold)

# %% [markdown]
# To avoid this problem we create a mask which will be used to exclude the top 5% brighest voxels (95th percentile) from registration.

# %%
inMask = sitk.BinaryThreshold(inImg, 0, imgPercentile(inImg, 0.95), 1, 0)
imgShow(inMask)

# %% [markdown]
# The masked areas will be excluded from the registration

# %%
imgShow(imgMask(inImg,inMask))

# %% [markdown]
# ## Downsample Images
# Ideally we would do resgistration at the full atlas scale of 0.01 mm x 0.01 x 0.01 mm but this would be far to computationally expensive for the purposes of this tutorial.  Therefore to save time we downsample the images to 0.1 mm x 0.1mm x 0.1mm

# %%
spacing_ds=[0.1,0.1,0.1]
refImg_ds = imgResample(refImg, spacing=spacing_ds)
imgShow(refImg_ds, vmax=refThreshold)

# %%
inImg_ds = imgResample(inImg, spacing=spacing_ds)
imgShow(inImg_ds, vmax=inThreshold)

# %% [markdown]
# Notice how we use nearest neighbor interpolation when downsampling the mask

# %%
inMask_ds = imgResample(inMask, spacing=spacing_ds, useNearest=True)
imgShow(inMask_ds)

# %% [markdown]
# ## Generating ARA Mask
# Notice how our input image is we only have half of a CLARITY brain.  Therefore we should only use half of the ARA during registration.  To do this we generate a mask of the ARA which excludes half of the brain.

# %%
refSize_ds = refImg_ds.GetSize()
refArraySize_ds = np.array(refSize_ds)[::-1]
refMaskArray_ds = np.zeros(refArraySize_ds)
start = refArraySize_ds[-1]/2
refMaskArray_ds[:,:,:start] = 1
refMask_ds = sitk.GetImageFromArray(refMaskArray_ds)
refMask_ds.SetSpacing(spacing_ds)

# %% [markdown]
# Thus we'll register the half CLARITY brain to half of the ARA

# %%
refImg_ds = imgMask(refImg_ds, refMask_ds)
imgShow(refImg_ds)

# %% [markdown]
# ## Affine Registration
# Now we compute the affine transform.  Unlike in the [basic registration tutiorial](basicRegistration.ipynb) we'll use the *imgAffineComposite* instead of *imgAffine*.  *imgAffine* simply computes the affine transform between the input and reference images.  *imgAffineComposite* computes a translation then a rigid then an affine transformation.  It's output is the composition of those three transforms.  We use Mutual Information since the CLARITY and ARA images have very differnt intensity profiles.  We also enable the *verbose* option so that each iteration is printed.

# %%
affine = imgAffineComposite(inImg_ds, refImg_ds, inMask=inMask_ds, iterations=200, useMI=True, verbose=True)
# Out:
# Step translation:
# 0.	 -0.107839542411
# 1.	 -0.108786533811
# 2.	 -0.113106992856
# 3.	 -0.117985062352
# 4.	 -0.128819692375
# 5.	 -0.136237908176
# 6.	 -0.146940316351
# 7.	 -0.158069905466
# 8.	 -0.167767777116
# 9.	 -0.179832736039
# 10.	 -0.198022547692
# 11.	 -0.209361612005
# 12.	 -0.220477285302
# 13.	 -0.234120623105
# 14.	 -0.24662797622
# 15.	 -0.255159513902
# 16.	 -0.259728151964
# 17.	 -0.265946768945
# 18.	 -0.271255569873
# 19.	 -0.279172054723
# 20.	 -0.282857042248
# 21.	 -0.291091293871
# 22.	 -0.288292034093
# 23.	 -0.298918301404
# 24.	 -0.300920356266
# 25.	 -0.300939611466
# 26.	 -0.3081846611
# 27.	 -0.307205708437
# 28.	 -0.308547477804
# 29.	 -0.311967904439
# 30.	 -0.30086340651
# 31.	 -0.307446873665
# 32.	 -0.308464838101
# 33.	 -0.303616543363
# 34.	 -0.30853157147
# 35.	 -0.30851958381
# 36.	 -0.303549168287
# 37.	 -0.308478178812
# 38.	 -0.308464014395
# Step scale:
# 0.	 -0.314800845304
# 1.	 -0.300541033678
# 2.	 -0.2993765248
# 3.	 -0.310859032476
# 4.	 -0.314267283109
# 5.	 -0.316915008758
# 6.	 -0.321978393892
# 7.	 -0.319457387553
# 8.	 -0.319569400241
# 9.	 -0.319619465192
# 10.	 -0.322091556327
# 11.	 -0.321779856284
# 12.	 -0.322661811928
# 13.	 -0.322887113829
# 14.	 -0.326055944605
# 15.	 -0.328909530214
# 16.	 -0.327760689402
# 17.	 -0.329058579498
# 18.	 -0.329240837116
# 19.	 -0.330678861728
# 20.	 -0.332626490989
# 21.	 -0.331093432486
# 22.	 -0.331635197029
# 23.	 -0.333227012364
# 24.	 -0.332644582366
# 25.	 -0.333092404286
# 26.	 -0.333684059881
# Step rigid:
# 0.	 -0.3405971303
# 1.	 -0.222585438001
# 2.	 -0.330166629927
# 3.	 -0.332491522496
# 4.	 -0.360887977389
# 5.	 -0.357399811588
# 6.	 -0.361030371194
# 7.	 -0.359664166599
# 8.	 -0.364027939959
# 9.	 -0.362003173528
# 10.	 -0.366886758802
# 11.	 -0.364279895208
# 12.	 -0.369405252853
# 13.	 -0.366830359161
# 14.	 -0.371445576616
# 15.	 -0.369139385662
# 16.	 -0.373904754714
# 17.	 -0.37141208999
# 18.	 -0.376239133208
# 19.	 -0.373631138512
# 20.	 -0.378571764652
# 21.	 -0.377304851024
# 22.	 -0.378096882715
# 23.	 -0.378973010652
# 24.	 -0.379756016393
# 25.	 -0.380554360094
# 26.	 -0.381400167426
# 27.	 -0.382142937786
# 28.	 -0.382936144442
# 29.	 -0.383498293719
# 30.	 -0.384208328412
# 31.	 -0.38494513554
# 32.	 -0.38569581251
# 33.	 -0.386191954017
# 34.	 -0.387049537061
# 35.	 -0.387511420107
# 36.	 -0.388303010967
# 37.	 -0.388870013003
# 38.	 -0.389731549302
# 39.	 -0.390199898254
# 40.	 -0.390898706657
# 41.	 -0.391353229587
# 42.	 -0.392259364147
# 43.	 -0.392608562318
# 44.	 -0.393299958648
# 45.	 -0.393534021958
# 46.	 -0.394700929463
# 47.	 -0.394351385981
# 48.	 -0.39587142301
# 49.	 -0.395112756638
# 50.	 -0.397199141386
# 51.	 -0.3958670569
# 52.	 -0.398120238859
# 53.	 -0.397375683174
# 54.	 -0.397663426844
# 55.	 -0.39790722302
# 56.	 -0.398201097202
# 57.	 -0.398520640842
# 58.	 -0.398768994498
# 59.	 -0.399134054035
# 60.	 -0.399305645172
# 61.	 -0.399592911264
# 62.	 -0.399805109945
# 63.	 -0.400055800126
# 64.	 -0.400177654685
# 65.	 -0.4004798408
# 66.	 -0.400747645791
# 67.	 -0.400962823693
# 68.	 -0.401151269207
# 69.	 -0.401349136744
# 70.	 -0.401531113361
# 71.	 -0.401766941636
# 72.	 -0.401976821989
# 73.	 -0.402164453545
# 74.	 -0.402393753191
# 75.	 -0.402602758321
# 76.	 -0.40299725137
# 77.	 -0.403110088627
# 78.	 -0.403394687533
# 79.	 -0.403502352277
# 80.	 -0.403952339722
# 81.	 -0.403904142048
# 82.	 -0.404413659154
# 83.	 -0.404341453597
# 84.	 -0.404952362649
# 85.	 -0.40470804544
# 86.	 -0.405313856036
# 87.	 -0.404991918236
# 88.	 -0.405775719792
# 89.	 -0.40536745015
# 90.	 -0.406243799906
# 91.	 -0.405724733017
# 92.	 -0.406705641413
# 93.	 -0.40610805899
# 94.	 -0.407004160319
# 95.	 -0.406422531678
# 96.	 -0.407343326266
# 97.	 -0.406726762933
# 98.	 -0.40763951844
# 99.	 -0.407131127805
# 100.	 -0.408052025593
# 101.	 -0.407521546503
# 102.	 -0.408442792452
# 103.	 -0.407896454128
# 104.	 -0.408800898294
# 105.	 -0.408182512816
# 106.	 -0.409198842315
# 107.	 -0.408548066946
# 108.	 -0.409539125288
# 109.	 -0.408886955365
# 110.	 -0.409841613912
# 111.	 -0.409207255268
# 112.	 -0.41022156763
# 113.	 -0.409481068818
# 114.	 -0.410462421486
# 115.	 -0.409771455979
# 116.	 -0.410907984844
# 117.	 -0.410177958066
# 118.	 -0.411252510223
# 119.	 -0.410572402218
# 120.	 -0.411565908696
# 121.	 -0.410866994636
# 122.	 -0.411833030958
# 123.	 -0.411176436575
# 124.	 -0.412179117736
# 125.	 -0.411548648886
# 126.	 -0.412544764368
# 127.	 -0.411876437051
# 128.	 -0.412861147275
# 129.	 -0.412152324299
# 130.	 -0.413227979562
# 131.	 -0.412548354147
# 132.	 -0.413559851522
# 133.	 -0.412857813347
# 134.	 -0.413877688889
# 135.	 -0.413182689404
# 136.	 -0.414232803851
# 137.	 -0.413473697329
# 138.	 -0.414586940039
# 139.	 -0.413794597788
# 140.	 -0.41488880956
# 141.	 -0.414166246196
# 142.	 -0.415188184352
# 143.	 -0.41443582622
# 144.	 -0.415466440534
# 145.	 -0.414638824081
# 146.	 -0.415730210531
# 147.	 -0.41501402454
# 148.	 -0.416037654996
# 149.	 -0.415399405042
# 150.	 -0.416431186188
# 151.	 -0.415685498579
# 152.	 -0.416789824717
# 153.	 -0.416058529622
# 154.	 -0.417102139002
# 155.	 -0.416402339291
# 156.	 -0.417379489014
# 157.	 -0.416614072524
# 158.	 -0.417637910158
# 159.	 -0.417006436319
# 160.	 -0.417949787505
# 161.	 -0.417268389122
# 162.	 -0.418254453304
# 163.	 -0.417569640796
# 164.	 -0.418552679963
# 165.	 -0.417840868938
# 166.	 -0.418824659176
# 167.	 -0.418164775293
# 168.	 -0.419148069465
# 169.	 -0.41844081398
# 170.	 -0.419472661718
# 171.	 -0.41872940148
# 172.	 -0.419800134657
# 173.	 -0.419064022237
# 174.	 -0.420173882715
# 175.	 -0.419407471992
# 176.	 -0.420432445407
# 177.	 -0.419664491617
# 178.	 -0.420778379834
# 179.	 -0.419943582551
# 180.	 -0.421080782704
# 181.	 -0.420248324176
# 182.	 -0.421319887623
# 183.	 -0.420414983168
# 184.	 -0.421629528836
# 185.	 -0.420695757349
# 186.	 -0.421921456442
# 187.	 -0.420965251719
# 188.	 -0.422219758873
# 189.	 -0.421264662401
# 190.	 -0.422526939548
# 191.	 -0.421633659345
# 192.	 -0.42275163951
# 193.	 -0.42198439959
# 194.	 -0.423044584583
# 195.	 -0.422263589624
# 196.	 -0.423407603606
# 197.	 -0.422551316823
# 198.	 -0.423724024029
# 199.	 -0.42285142927
# Step affine:
# 0.	 -0.420054448242
# 1.	 -0.430175964703
# 2.	 -0.441279684099
# 3.	 -0.484053266283
# 4.	 -0.478612764879
# 5.	 -0.485222905745
# 6.	 -0.483231486208
# 7.	 -0.490070980429
# 8.	 -0.485364593866
# 9.	 -0.493445659868
# 10.	 -0.489349433503
# 11.	 -0.496231361608
# 12.	 -0.492752519911
# 13.	 -0.493011619959
# 14.	 -0.494846737113
# 15.	 -0.494920882878
# 16.	 -0.496651570516
# 17.	 -0.497839873463
# 18.	 -0.499104075277
# 19.	 -0.500645140817
# 20.	 -0.501841239783
# 21.	 -0.503169615317
# 22.	 -0.504289424604
# 23.	 -0.505215457322
# 24.	 -0.506211892999
# 25.	 -0.506540469166
# 26.	 -0.507390863432
# 27.	 -0.507134578445
# 28.	 -0.508362350712
# 29.	 -0.507181088125
# 30.	 -0.509528173135
# 31.	 -0.507112209941
# 32.	 -0.510288888982
# 33.	 -0.507537028097
# 34.	 -0.509187223257
# 35.	 -0.50938508136
# 36.	 -0.509547023605
# 37.	 -0.509679843577
# 38.	 -0.50977846974
# 39.	 -0.509837136118
# 40.	 -0.509914956823
# 41.	 -0.510159154302
# 42.	 -0.510190820489
# 43.	 -0.510247013639
# 44.	 -0.510267449953
# 45.	 -0.510440231078
# 46.	 -0.51046232383
# 47.	 -0.510500288365
# 48.	 -0.510454207073
# 49.	 -0.510404253335
# 50.	 -0.510455091175
# 51.	 -0.510353319405
# 52.	 -0.510374444199
# 53.	 -0.510427877519
# 54.	 -0.510464758797
# 55.	 -0.510546046369
# 56.	 -0.510622301985
# 57.	 -0.510683515489
# 58.	 -0.510741805066
# 59.	 -0.510769178685
# 60.	 -0.510701018114
# 61.	 -0.510881657623
# 62.	 -0.510659507693
# 63.	 -0.510928662344
# 64.	 -0.510631656723
# 65.	 -0.51087984625
# 66.	 -0.510580743132
# 67.	 -0.510846759672

# %% [markdown]
# Now we apply the affine transform to the input CLARITY image and mask

# %%
inImg = imgApplyAffine(inImg, affine, size=refImg.GetSize())
imgShow(inImg, vmax=inThreshold)
inMask = imgApplyAffine(inMask, affine, size=refImg.GetSize(), useNearest=True)

# %% [markdown]
# ## LDDMM registration
# Now we run LDDMM registration. Here we use *imgMetamorphosisComposite*.  Unlike *imgMetamorphosis* introduced in the [2D registration notebook](2D_Registration.ipynb), this function runs LDDMM in multiple steps using the alpha values specified by in *alphaList*. The *field* and *invField* outputs are the composition of all steps.  Once agan we use a Mutual Information cost because the input CLARITY brain and reference ARA average have very differnt intensity profiles.

# %%
inImg_ds = imgResample(inImg, spacing=spacing_ds)
inMask_ds = imgResample(inMask, spacing=spacing_ds, useNearest=True)
(field, invField) = imgMetamorphosisComposite(inImg_ds, refImg_ds, inMask=inMask_ds, alphaList=[0.05, 0.02,0.01], scaleList = [0.25, 0.5, 1.0], useMI=True, iterations=100, verbose=True)
inImg = imgApplyField(inImg, field, size=refImg.GetSize())
inMask = imgApplyField(inMask, field, size=refImg.GetSize(), useNearest=True)
imgShow(inImg, vmax=inThreshold)
imgShow(inMask)
# Out:
# Step 0: alpha=0.05, beta=0.05, scale=0.25
# 	E, E_velocity, E_rate, E_image (E_image %), LearningRate
# 0.	-1.2948e+10, 7.2308, 0, -1.2948e+10 (99.7913%), 1.718750e-05
# 1.	-1.32044e+10, 9.79888, 0, -1.32044e+10 (99.3684%), 1.890625e-05
# 2.	-1.35066e+10, 16.4231, 0, -1.35066e+10 (98.8699%), 2.079688e-05
# 3.	-1.35314e+10, 19.328, 0, -1.35314e+10 (98.8291%), 1.143828e-05
# E = -1.35314e+10 (98.8291%)
# Length = 6.69428
# Time = 19.8831s (0.331385m)
#
# Step 1: alpha=0.02, beta=0.05, scale=0.5
# 	E, E_velocity, E_rate, E_image (E_image %), LearningRate
# 0.	-1.06391e+10, 113.688, 0, -1.06391e+10 (98.0428%), 1.100000e-03
# 1.	-1.1018e+10, 196.315, 0, -1.1018e+10 (97.4346%), 1.210000e-03
# 2.	-1.13882e+10, 245.79, 0, -1.13882e+10 (96.8402%), 6.655000e-04
# 3.	-1.21933e+10, 266.89, 0, -1.21933e+10 (95.5478%), 3.660250e-04
# 4.	-1.22532e+10, 296.251, 0, -1.22532e+10 (95.4516%), 4.026275e-04
# 5.	-1.23704e+10, 336.268, 0, -1.23704e+10 (95.2635%), 4.428903e-04
# 6.	-1.25073e+10, 353.872, 0, -1.25073e+10 (95.0437%), 2.435896e-04
# 7.	-1.2687e+10, 382.237, 0, -1.2687e+10 (94.7553%), 2.679486e-04
# 8.	-1.27558e+10, 410.025, 0, -1.27558e+10 (94.6448%), 2.947435e-04
# 9.	-1.29238e+10, 446.494, 0, -1.29238e+10 (94.3751%), 3.242178e-04
# 10.	-1.29653e+10, 452.709, 0, -1.29653e+10 (94.3085%), 8.915990e-05
# 11.	-1.29702e+10, 457.593, 0, -1.29702e+10 (94.3007%), 4.903794e-05
# 12.	-1.2978e+10, 460.352, 0, -1.2978e+10 (94.2881%), 2.697087e-05
# 13.	-1.29803e+10, 461.887, 0, -1.29803e+10 (94.2844%), 1.483398e-05
# 14.	-1.29841e+10, 463.535, 0, -1.29841e+10 (94.2783%), 1.631738e-05
# 15.	-1.29846e+10, 463.765, 0, -1.29846e+10 (94.2774%), 2.243639e-06
# 16.	-1.29849e+10, 463.828, 0, -1.29849e+10 (94.277%), 6.170008e-07
# 17.	-1.29849e+10, 463.837, 0, -1.29849e+10 (94.277%), 8.483761e-08
# 18.	-1.29849e+10, 463.84, 0, -1.29849e+10 (94.2769%), 2.333034e-08
# 19.	-1.29849e+10, 463.84, 0, -1.29849e+10 (94.2769%), 6.415844e-09
# 	E, E_velocity, E_rate, E_image (E_image %), LearningRate
# 20.	-1.29849e+10, 463.841, 0, -1.29849e+10 (94.2769%), 3.528714e-09
# 21.	-1.29849e+10, 463.841, 0, -1.29849e+10 (94.2769%), 1.940793e-09
# 22.	-1.29849e+10, 463.841, 0, -1.29849e+10 (94.2769%), 5.337180e-10
# E = -1.29839e+10 (94.2786%)
# Length = 26.9945
# Time = 118.164s (1.9694m)
#
# Step 2: alpha=0.01, beta=0.05, scale=1.0
# 	E, E_velocity, E_rate, E_image (E_image %), LearningRate
# 0.	-1.22469e+10, 1.09892, 0, -1.22469e+10 (99.4567%), 1.100000e-03
# 1.	-1.22988e+10, 3.93691, 0, -1.22988e+10 (99.3688%), 1.210000e-03
# 2.	-1.23005e+10, 8.89083, 0, -1.23005e+10 (99.3659%), 1.331000e-03
# 3.	-1.25181e+10, 15.3746, 0, -1.25181e+10 (98.9974%), 1.464100e-03
# 4.	-1.27935e+10, 18.4159, 0, -1.27935e+10 (98.5311%), 8.052550e-04
# 5.	-1.30076e+10, 22.704, 0, -1.30076e+10 (98.1685%), 8.857805e-04
# 6.	-1.30832e+10, 28.8701, 0, -1.30832e+10 (98.0405%), 9.743586e-04
# 7.	-1.31663e+10, 32.584, 0, -1.31663e+10 (97.8997%), 5.358972e-04
# 8.	-1.32079e+10, 36.9569, 0, -1.32079e+10 (97.8292%), 5.894869e-04
# 9.	-1.32614e+10, 42.1741, 0, -1.32614e+10 (97.7387%), 6.484356e-04
# 10.	-1.32771e+10, 48.2668, 0, -1.32771e+10 (97.712%), 7.132792e-04
# 11.	-1.33577e+10, 55.48, 0, -1.33577e+10 (97.5756%), 7.846071e-04
# 12.	-1.34934e+10, 59.1254, 0, -1.34934e+10 (97.3457%), 4.315339e-04
# 13.	-1.3566e+10, 63.4338, 0, -1.3566e+10 (97.2229%), 4.746873e-04
# 14.	-1.36187e+10, 68.3618, 0, -1.36187e+10 (97.1335%), 5.221560e-04
# 15.	-1.36682e+10, 74.0034, 0, -1.36682e+10 (97.0497%), 5.743716e-04
# 16.	-1.36832e+10, 80.3785, 0, -1.36832e+10 (97.0243%), 6.318088e-04
# 17.	-1.3702e+10, 87.7215, 0, -1.3702e+10 (96.9925%), 6.949897e-04
# 18.	-1.37994e+10, 91.5582, 0, -1.37994e+10 (96.8276%), 3.822443e-04
# 19.	-1.38542e+10, 96.059, 0, -1.38542e+10 (96.7347%), 4.204687e-04
# 	E, E_velocity, E_rate, E_image (E_image %), LearningRate
# 20.	-1.38927e+10, 101.156, 0, -1.38927e+10 (96.6696%), 4.625156e-04
# 21.	-1.39474e+10, 106.971, 0, -1.39474e+10 (96.5769%), 5.087672e-04
# 22.	-1.39742e+10, 113.538, 0, -1.39742e+10 (96.5315%), 5.596439e-04
# 23.	-1.39903e+10, 121.128, 0, -1.39903e+10 (96.5043%), 6.156083e-04
# 24.	-1.40971e+10, 125.03, 0, -1.40971e+10 (96.3235%), 3.385846e-04
# 25.	-1.41417e+10, 129.593, 0, -1.41417e+10 (96.2478%), 3.724430e-04
# 26.	-1.41544e+10, 134.684, 0, -1.41544e+10 (96.2263%), 4.096873e-04
# 27.	-1.41929e+10, 140.398, 0, -1.41929e+10 (96.1611%), 4.506561e-04
# 28.	-1.42181e+10, 146.755, 0, -1.42181e+10 (96.1185%), 4.957217e-04
# 29.	-1.42227e+10, 154.142, 0, -1.42227e+10 (96.1106%), 5.452938e-04
# 30.	-1.42962e+10, 157.852, 0, -1.42962e+10 (95.9862%), 2.999116e-04
# 31.	-1.43282e+10, 162.152, 0, -1.43282e+10 (95.932%), 3.299028e-04
# 32.	-1.43597e+10, 166.831, 0, -1.43597e+10 (95.8788%), 3.628930e-04
# 33.	-1.43827e+10, 172.201, 0, -1.43827e+10 (95.8397%), 3.991823e-04
# 34.	-1.4411e+10, 177.93, 0, -1.4411e+10 (95.7918%), 4.391006e-04
# 35.	-1.44383e+10, 181.229, 0, -1.44383e+10 (95.7456%), 2.415053e-04
# 36.	-1.44646e+10, 184.74, 0, -1.44646e+10 (95.701%), 2.656558e-04
# 37.	-1.44834e+10, 188.747, 0, -1.44834e+10 (95.6693%), 2.922214e-04
# 38.	-1.45104e+10, 193.013, 0, -1.45104e+10 (95.6236%), 3.214436e-04
# 39.	-1.45231e+10, 197.872, 0, -1.45231e+10 (95.602%), 3.535879e-04
# 	E, E_velocity, E_rate, E_image (E_image %), LearningRate
# 40.	-1.45464e+10, 203.012, 0, -1.45464e+10 (95.5626%), 3.889467e-04
# 41.	-1.45658e+10, 206.008, 0, -1.45658e+10 (95.5297%), 2.139207e-04
# 42.	-1.45859e+10, 209.166, 0, -1.45859e+10 (95.4956%), 2.353128e-04
# 43.	-1.46012e+10, 212.743, 0, -1.46012e+10 (95.4698%), 2.588440e-04
# 44.	-1.46211e+10, 216.659, 0, -1.46211e+10 (95.436%), 2.847285e-04
# 45.	-1.46353e+10, 221.08, 0, -1.46353e+10 (95.412%), 3.132013e-04
# 46.	-1.46567e+10, 225.709, 0, -1.46567e+10 (95.3758%), 3.445214e-04
# 47.	-1.4681e+10, 231.044, 0, -1.4681e+10 (95.3346%), 3.789736e-04
# 48.	-1.47103e+10, 233.745, 0, -1.47103e+10 (95.285%), 2.084355e-04
# 49.	-1.47245e+10, 236.757, 0, -1.47245e+10 (95.2609%), 2.292790e-04
# 50.	-1.47381e+10, 240.179, 0, -1.47381e+10 (95.238%), 2.522069e-04
# 51.	-1.47493e+10, 243.979, 0, -1.47493e+10 (95.2189%), 2.774276e-04
# 52.	-1.47635e+10, 248.124, 0, -1.47635e+10 (95.1948%), 3.051704e-04
# 53.	-1.47743e+10, 252.884, 0, -1.47743e+10 (95.1765%), 3.356874e-04
# 54.	-1.47749e+10, 257.994, 0, -1.47749e+10 (95.1755%), 3.692561e-04
# 55.	-1.47771e+10, 263.812, 0, -1.47771e+10 (95.1719%), 4.061818e-04
# 56.	-1.48221e+10, 266.712, 0, -1.48221e+10 (95.0956%), 2.234000e-04
# 57.	-1.48418e+10, 269.961, 0, -1.48418e+10 (95.0623%), 2.457400e-04
# 58.	-1.48448e+10, 270.879, 0, -1.48448e+10 (95.0572%), 6.757849e-05
# 59.	-1.48467e+10, 271.385, 0, -1.48467e+10 (95.054%), 3.716817e-05
# 	E, E_velocity, E_rate, E_image (E_image %), LearningRate
# 60.	-1.48467e+10, 271.42, 0, -1.48467e+10 (95.0539%), 2.555312e-06
# 61.	-1.48468e+10, 271.425, 0, -1.48468e+10 (95.0539%), 3.513553e-07
# 62.	-1.48468e+10, 271.426, 0, -1.48468e+10 (95.0539%), 9.662272e-08
# 63.	-1.48468e+10, 271.426, 0, -1.48468e+10 (95.0539%), 6.642812e-09
# 64.	-1.48468e+10, 271.426, 0, -1.48468e+10 (95.0539%), 3.653547e-09
# 65.	-1.48468e+10, 271.426, 0, -1.48468e+10 (95.0539%), 2.009451e-09
# 66.	-1.48468e+10, 271.426, 0, -1.48468e+10 (95.0539%), 2.762995e-10
# E = -1.48366e+10 (95.0711%)
# Length = 19.6148
# Time = 1146.07s (19.1011m)

# %% [markdown]
# ## Evaluating the registration
# ### Evaluation using checker board
# We can evaluate the registration by generating a checkerboard of the deformed CLARITY and ARA.  In this method the input image is placed on the black squares of the metaphorical checkerboard while the reference image is placed on the red squares.  Idealy anatomical sturctures should line up across squares.

# %%
imgShow(imgChecker(inImg, refImg, useHM=False), vmax=refThreshold, numSlices=1)

# %% [markdown]
# ## Uploading Results
#
# ### Uploading deformed CLARITY image
# We can now upload the ARA-aligned CLARITY brain back into ndstore.

# %%
token = inToken+"_to_ara3"
imgUpload(inImg, token)

# %% [markdown]
# ### Uploading deformed ARA annotations

# %% [markdown]
# To save memory we clear some images that are no longer needed.

# %%
#inImg = None
refImg = None

# %% [markdown]
# Now we download the ARA annotations

# %%
refAnnoImg = imgDownload(refToken, channel="annotation")

# %% [markdown]
# Since our input is only a half brain we only use half of the annotations.

# %%
refAnnoImg2 = sitk.Image(refAnnoImg.GetSize(), refAnnoImg.GetPixelID())
refAnnoImg2.CopyInformation(refAnnoImg)
halfSize = list(refAnnoImg.GetSize())
halfSize[0]/=2
refAnnoImg = sitk.Paste(refAnnoImg2, refAnnoImg, halfSize)
refAnnoImg2 = None # Delete to save memory
imgShow(refAnnoImg,vmax=500)

# %% [markdown]
# Before we can overlay the ARA annotations on the downloaded image we must transfom them to its space. Fortunatly this can be done since all spatial transforms in this tutorial are invertable.  First we construct an inverse displacement field which transforms the annotations from the ARA space to the space before registration. To save memory this new field will be stored at a downampled resolution.

# %%
size_ds = np.ceil(np.array(refAnnoImg.GetSize())*np.array(refAnnoImg.GetSpacing())/np.array(spacing_ds))
size_ds = list(size_ds.astype(int))
invAffine = affineInverse(affine)
invAffineField = affineToField(invAffine, size_ds, spacing_ds)
invField = fieldApplyField(invAffineField, invField)

# %% [markdown]
# Next we apply it to the reference annotations

# %%
inAnnoImg = imgApplyField(refAnnoImg, invField,useNearest=True, size=inImgSize_reorient, spacing=inImgSpacing_reorient)
imgShow(inAnnoImg, vmax=500)

# %% [markdown]
# We're not done yet.  We still need to reorient these annotations from **RSA** to the native **IPL**  orientation

# %%
inAnnoImg = imgReorient(inAnnoImg, refOrient, inOrient)
imgShow(inAnnoImg, vmax=500)

# %% [markdown]
# Finally we upload these annotations at the resolution we downloaded the input image

# %%
outToken = "ara3_to_"+inToken
imgUpload(inAnnoImg, outToken, resolution=inResolution)
