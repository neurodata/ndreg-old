# %%
# %matplotlib inline

# %% [markdown]
# # Volumetric Registration and Analysis
# In this tutorial we align a CLARITY brain to the Allen Reference Atlas (ARA).  Thus the ARA is our _reference_ image, it consists of image data stored in the default "average" channel and corresponding annotations stored in a separate "annotation" channel.  We begin by importing the relevant modules

# %%
from ndreg import *
import matplotlib
import ndio.remote.neurodata as neurodata

# %% [markdown]
# ## Downloading Atlas
# First we'll download the atlas image

# %%
refToken = "ara_ccf3"
refImg = imgDownload(refToken)

# %% [markdown]
# Next we'll visuaize the image.  To ensure that the visuization is has good contrast we'll only show intensity values below the 99th percentile.

# %%
refThreshold = imgPercentile(refImg, 0.99)
print(refThreshold)
# Out:
# 269.129411765

# %% [markdown]
# When given an image volume *imgShow* displays it as a set of evenly spaced z-slices (1st column), y-slices (2nd column) and x slices (3rd column).

# %%
imgShow(refImg, vmax=refThreshold)

# %% [markdown]
# ## Downloading CLARITY brain
# Our *input* image will be the CLARITY brain.  At full resolution, CLARITY brains can be 1 Terabyte in size, far to large to be downloaded to a personal computer.  Thus *ndstore* stores the brains at multiple resolutions. Resolution 0 is always the highest resolution each subsequent resoltion takes up 1/4th (under slice scaling) or 1/8th (under isotropic scaling) as many bytes as the previous resoltion.  Lets look at the resolution of the ARA

# %%
print(refImg.GetSpacing())
# Out:
# (0.01, 0.01, 0.01)

# %% [markdown]
# It is 0.01 X 0.01 X 0.01 mm (10 x 10 x 10 um).  Therefore we'll want to download the CLARITY brain at a simmilar resolution. We can use ndio's get_metadata method to see a list of available resoltions.

# %%
inToken = "154DLS_tail"
inChannel = "ch0"
nd = neurodata()
resolutionDict = nd.get_metadata(inToken)['dataset']['voxelres']
resolutionList = map(int,resolutionDict.keys())
resolutionList.sort()
for resolution in resolutionList:
    print(resolution, resolutionDict[str(resolution)])
# Out:
# (0, [585.0, 585.0, 5000.0])
# (1, [1170.0, 1170.0, 5000.0])
# (2, [2340.0, 2340.0, 5000.0])
# (3, [4680.0, 4680.0, 5000.0])
# (4, [9360.0, 9360.0, 5000.0])
# (5, [18720.0, 18720.0, 5000.0])
# (6, [37440.0, 37440.0, 5000.0])
# (7, [74880.0, 74880.0, 5000.0])
# (8, [149760.0, 149760.0, 5000.0])
# (9, [299520.0, 299520.0, 5000.0])
# (10, [599040.0, 599040.0, 5000.0])

# %% [markdown]
# Resolution 4 is 9.36 x 9.36 x 5 um is the closest to what we want.  So we'll download the CLARITY image at that resolution.  Depending on your internet connection downloading may take several minutes.

# %%
inImg = imgDownload(inToken, inChannel, resolution=4)

# %% [markdown]
# Once again we'll only use intensity values below the 99th percentile in the visualization.

# %% [markdown]
# ## Reorienting CLARITY image
# You may have noticed that the CLARITY brain is not oriented in the same way as the atlas.  Let's look at the atlas.

# %%
inThreshold = imgPercentile(inImg, 0.99)
imgShow(inImg, vmax=inThreshold)

# %%
imgShow(refImg, vmax=refThreshold)

# %% [markdown]
# By examining the the z slices in the first column its clear that the x-axis goes from **R**ight to Left side of the brain. The y-axis varies from **S**uperior to Inferior and the z-axis goes from **A**nterior to posterior.  Thus it is in **RSA** orientation.  Looking at the the CLARITY brain...

# %%
imgShow(inImg, vmax=inThreshold)

# %% [markdown]
# ...we see that the x-axis goes from **I**nferior to Superior, the y-axis goes from **P**osterior to Anterior and the Z axis goes from **L**eft to Right.  Thus it's in **IPL** orientation.  Therefore we reorient the CLARITY image from **IPL** to **RSA**

# %%
inOrient = "PLI"
refOrient = "RSA"
inImg = imgReorient(inImg, inOrient, refOrient)
imgShow(inImg, vmax=inThreshold)

# %% [markdown]
# Compare the above to the Atlas.  The slices should now correspond with the atlas even though in this case we only have half of a CLARITY brain. Let's make a copy of the reorianted image size and spacing because we'll need it later.

# %%
inImgSize_reorient = inImg.GetSize()
inImgSpacing_reorient= inImg.GetSpacing()

# %% [markdown]
# ## Resampling CLARITY image
# Notice how the CLARITY brain's resolution is higher than the ARA image that we want to align it to.

# %%
print(inImg.GetSpacing())
# Out:
# (0.005, 0.00936, 0.00936)

# %%
print(refImg.GetSpacing())
# Out:
# (0.01, 0.01, 0.01)

# %% [markdown]
# Since we are aliging the CLARITY image to a lower resolution atlas we resample it to the resolution atlas.

# %%
inImg = imgResample(inImg, spacing=refImg.GetSpacing())
imgShow(inImg, vmax=inThreshold)

# %% [markdown]
# ## Thresholding CLARITY image
# Lets plot the histogram of the CLARITY image

# %%
(values, bins) = np.histogram(sitk.GetArrayFromImage(inImg), bins=100, range=(0,500))
plt.plot(bins[:-1], values)

# %% [markdown]
# Notice the huge spike at 100.  This occurs because the intensity of the background is about 100. Idealy we want a black background with an intensity of 0.  Therefore we'll threhold the image below 100 and then subtract 100 from the image.  Notice how we've recalculate the visualization threshold "inThreshold" since we've changed the intensity of the input image.

# %%
lowerThreshold = 100
upperThreshold = sitk.GetArrayFromImage(inImg).max()+1

inImg = sitk.Threshold(inImg,lowerThreshold,upperThreshold,lowerThreshold) - lowerThreshold
inThreshold -= lowerThreshold

imgShow(inImg, vmax=inThreshold)

# %% [markdown]
# Here's a histogram of the result

# %%
(values, bins) = np.histogram(sitk.GetArrayFromImage(inImg), bins=100, range=(0,500))
plt.plot(bins[:-1], values)

# %% [markdown]
# ## Generating CLARITY mask
# CLARITY brains contain really brignt fluorescent spots in the cerebral cortex and thalamus which can interfer with the registration.

# %%
imgShow(inImg, vmax=inThreshold)

# %% [markdown]
# To avoid this problem we create a mask which will be used to exclude the top 5% brighest voxels (95th percentile) from registration.

# %%
inMask = sitk.BinaryThreshold(inImg, 0, imgPercentile(inImg, 0.95), 1, 0)
imgShow(inMask)

# %% [markdown]
# The masked areas will be excluded from the registration

# %%
imgShow(imgMask(inImg,inMask))

# %% [markdown]
# ## Downsample Images
# Ideally we would do resgistration at the full atlas scale of 0.01 mm x 0.01 x 0.01 mm but this would be far to computationally expensive for the purposes of this tutorial.  Therefore to save time we downsample the images to 0.1 mm x 0.1mm x 0.1mm

# %%
spacing=[0.1,0.1,0.1]
refImg_ds = imgResample(refImg, spacing=spacing)
imgShow(refImg_ds, vmax=refThreshold)

# %%
inImg_ds = imgResample(inImg, spacing=spacing)
imgShow(inImg_ds, vmax=inThreshold)

# %% [markdown]
# Notice how we use nearest neighbor interpolation when downsampling the mask

# %%
inMask_ds = imgResample(inMask, spacing=spacing, useNearest=True)
imgShow(inMask_ds)

# %% [markdown]
# ## Generating ARA Mask
# Notice how our input image is we only have half of a CLARITY brain.  Therefore we should only use half of the ARA during registration.  To do this we generate a mask of the ARA which excludes half of the brain.

# %%
refSize_ds = refImg_ds.GetSize()
refArraySize_ds = np.array(refSize_ds)[::-1]
refMaskArray_ds = np.zeros(refArraySize_ds)
start = refArraySize_ds[-1]/2
refMaskArray_ds[:,:,:start] = 1
refMask_ds = sitk.GetImageFromArray(refMaskArray_ds)
refMask_ds.SetSpacing(spacing)

# %% [markdown]
# Thus we'll register the half CLARITY brain to half of the ARA

# %%
refImg_ds = imgMask(refImg_ds, refMask_ds)
imgShow(refImg_ds)

# %% [markdown]
# ## Affine Registration
# Now we compute the affine transform.  Unlike in the [basic registration tutiorial](basicRegistration.ipynb) we'll use the *imgAffineComposite* instead of *imgAffine*.  *imgAffine* simply computes the affine transform between the input and reference images.  *imgAffineComposite* computes a translation then a rigid then an affine transformation.  It's output is the composition of those three transforms.  We use Mutual Information since the CLARITY and ARA images have very differnt intensity profiles.  We also enable the *verbose* option so that each iteration is printed.

# %%
affine = imgAffineComposite(inImg_ds, refImg_ds, inMask=inMask_ds, iterations=200, useMI=True, verbose=True)
# Out:
# Step translation:
# 0.	 -0.101815097124
# 1.	 -0.107748670546
# 2.	 -0.115099089382
# 3.	 -0.121325303226
# 4.	 -0.129129893118
# 5.	 -0.137243913063
# 6.	 -0.144949555491
# 7.	 -0.151587724726
# 8.	 -0.161315324108
# 9.	 -0.167245678864
# 10.	 -0.175977256699
# 11.	 -0.185650487228
# 12.	 -0.193385856997
# 13.	 -0.203084578203
# 14.	 -0.21123430301
# 15.	 -0.217514392354
# 16.	 -0.225376501977
# 17.	 -0.230605167012
# 18.	 -0.239422506828
# 19.	 -0.247043189266
# 20.	 -0.254798231872
# 21.	 -0.261366647936
# 22.	 -0.268720163933
# 23.	 -0.273445891363
# 24.	 -0.279937401853
# 25.	 -0.284343115049
# 26.	 -0.290461140673
# 27.	 -0.295295912114
# 28.	 -0.293892612127
# 29.	 -0.296596312954
# 30.	 -0.296532599958
# 31.	 -0.296907229124
# 32.	 -0.296566151948
# 33.	 -0.296562268487
# 34.	 -0.296920280162
# Step rigid:
# 0.	 -0.296448528468
# 1.	 -0.25475255383
# 2.	 -0.3407480721
# 3.	 -0.33686352526
# 4.	 -0.359356482567
# 5.	 -0.368855171703
# 6.	 -0.371207200017
# 7.	 -0.376875294511
# 8.	 -0.375860061665
# 9.	 -0.380025478574
# 10.	 -0.38205651967
# 11.	 -0.38333379867
# 12.	 -0.38503834216
# 13.	 -0.38545282067
# 14.	 -0.386867234647
# 15.	 -0.387197730092
# 16.	 -0.387626389305
# 17.	 -0.388161822661
# 18.	 -0.388605707802
# 19.	 -0.389024471205
# 20.	 -0.389439193249
# 21.	 -0.389777827322
# 22.	 -0.390104501986
# 23.	 -0.390342041103
# 24.	 -0.390669786496
# 25.	 -0.39089810673
# 26.	 -0.391133051728
# 27.	 -0.391125601767
# 28.	 -0.39141555041
# 29.	 -0.391444524142
# 30.	 -0.391562005143
# 31.	 -0.391623811197
# 32.	 -0.391761072601
# 33.	 -0.391722782783
# 34.	 -0.391898436015
# Step affine:
# 0.	 -0.39474803528
# 1.	 -0.329722343063
# 2.	 -0.426172572539
# 3.	 -0.425159480026
# 4.	 -0.436027092636
# 5.	 -0.432795744408
# 6.	 -0.437857789002
# 7.	 -0.438379768722
# 8.	 -0.43946036565
# 9.	 -0.440433287927
# 10.	 -0.441203347419
# 11.	 -0.442340585517
# 12.	 -0.442002953691
# 13.	 -0.442998170918
# 14.	 -0.443256244882
# 15.	 -0.44391015905
# 16.	 -0.443858527334
# 17.	 -0.444606796416
# 18.	 -0.444477000315
# 19.	 -0.445366672115
# 20.	 -0.445273008745
# 21.	 -0.44617389668
# 22.	 -0.445954596775
# 23.	 -0.446750905436
# 24.	 -0.446594579522
# 25.	 -0.447389407087
# 26.	 -0.447231136432
# 27.	 -0.448071479945
# 28.	 -0.447771556263
# 29.	 -0.448901372109
# 30.	 -0.44816149802
# 31.	 -0.449689200404
# 32.	 -0.448724112109
# 33.	 -0.450333904727
# 34.	 -0.449265639662
# 35.	 -0.450894401966
# 36.	 -0.449796129483
# 37.	 -0.451456038227
# 38.	 -0.45021546233
# 39.	 -0.451887845598
# 40.	 -0.450822791276
# 41.	 -0.452458632428
# 42.	 -0.451202896129
# 43.	 -0.4529041723
# 44.	 -0.45169223854
# 45.	 -0.453331931759
# 46.	 -0.452237951639
# 47.	 -0.453798615251
# 48.	 -0.452743127811
# 49.	 -0.45424231498
# 50.	 -0.453166095696
# 51.	 -0.454646477255
# 52.	 -0.453604309932
# 53.	 -0.455124955881
# 54.	 -0.454012197941
# 55.	 -0.455078127582
# 56.	 -0.455211526625
# 57.	 -0.455300137799
# 58.	 -0.455452510478
# 59.	 -0.455588708644
# 60.	 -0.455739636057
# 61.	 -0.455876357127
# 62.	 -0.456036761768
# 63.	 -0.456164632731
# 64.	 -0.45629750359
# 65.	 -0.456441573608
# 66.	 -0.456579344758
# 67.	 -0.456707735218
# 68.	 -0.456834658971
# 69.	 -0.456949526321
# 70.	 -0.45707419335
# 71.	 -0.457219892655
# 72.	 -0.457384940852
# 73.	 -0.457482184164
# 74.	 -0.457636595592
# 75.	 -0.45771614125
# 76.	 -0.457866001305
# 77.	 -0.458012648894
# 78.	 -0.45819077302
# 79.	 -0.458329441885
# 80.	 -0.458427839823
# 81.	 -0.458597148442
# 82.	 -0.458722233858
# 83.	 -0.458862593453
# 84.	 -0.458968394788
# 85.	 -0.459052554358
# 86.	 -0.45919505241
# 87.	 -0.45931501751
# 88.	 -0.459456055888
# 89.	 -0.459598084952
# 90.	 -0.459686531357
# 91.	 -0.459804507618
# 92.	 -0.459923467522
# 93.	 -0.460034200863
# 94.	 -0.460138605559
# 95.	 -0.460288265055
# 96.	 -0.460389775979
# 97.	 -0.460510324995
# 98.	 -0.460616164911
# 99.	 -0.460733815204
# 100.	 -0.460864911853
# 101.	 -0.461008661572
# 102.	 -0.461128003595
# 103.	 -0.461252644481
# 104.	 -0.461373958988
# 105.	 -0.461471632194
# 106.	 -0.46160785211
# 107.	 -0.461717496369
# 108.	 -0.461813995226
# 109.	 -0.461928445843
# 110.	 -0.462073120706
# 111.	 -0.462116976555
# 112.	 -0.462221371769
# 113.	 -0.462351865849
# 114.	 -0.462428217995
# 115.	 -0.462587580476
# 116.	 -0.462658059871
# 117.	 -0.462797896699
# 118.	 -0.46292847702
# 119.	 -0.463073531119
# 120.	 -0.463182687874
# 121.	 -0.463274071097
# 122.	 -0.463437859434
# 123.	 -0.463565465874
# 124.	 -0.463703931251
# 125.	 -0.463832505095
# 126.	 -0.463956261935
# 127.	 -0.4641345992
# 128.	 -0.46424372676
# 129.	 -0.464380822694
# 130.	 -0.464495357398
# 131.	 -0.464617103889
# 132.	 -0.464741716325
# 133.	 -0.464840807148
# 134.	 -0.464935619489
# 135.	 -0.465004233743
# 136.	 -0.465096513499
# 137.	 -0.465200643876
# 138.	 -0.465331680936
# 139.	 -0.465440077972
# 140.	 -0.465520439509
# 141.	 -0.465612368922
# 142.	 -0.465658933317
# 143.	 -0.465768286207
# 144.	 -0.465831609365
# 145.	 -0.465958134963
# 146.	 -0.466040436136
# 147.	 -0.466142379442
# 148.	 -0.466199535625
# 149.	 -0.466288864115
# 150.	 -0.466405925813
# 151.	 -0.466464476603
# 152.	 -0.466536763722
# 153.	 -0.466640658218
# 154.	 -0.466691811016
# 155.	 -0.466760178024
# 156.	 -0.466779992479
# 157.	 -0.466911250813
# 158.	 -0.466991085542
# 159.	 -0.46704551806
# 160.	 -0.467099646969
# 161.	 -0.467173140468
# 162.	 -0.467248752656
# 163.	 -0.467283014618
# 164.	 -0.467350924356
# 165.	 -0.467442964937
# 166.	 -0.467504969405
# 167.	 -0.467563876336
# 168.	 -0.467640617821
# 169.	 -0.46770974385
# 170.	 -0.467725417795
# 171.	 -0.467828595314
# 172.	 -0.467866134132
# 173.	 -0.467936006299
# 174.	 -0.468009655439
# 175.	 -0.468070923328
# 176.	 -0.468106965017
# 177.	 -0.468183512354
# 178.	 -0.468300187109
# 179.	 -0.468368666475
# 180.	 -0.468461960544
# 181.	 -0.468502942543
# 182.	 -0.468573504664
# 183.	 -0.468606950623
# 184.	 -0.468656539599
# 185.	 -0.468673766716
# 186.	 -0.468764518518
# 187.	 -0.468822623104
# 188.	 -0.468915238547
# 189.	 -0.468940517405
# 190.	 -0.469026545051
# 191.	 -0.469076937679
# 192.	 -0.469091114295
# 193.	 -0.469172403944
# 194.	 -0.469241040913
# 195.	 -0.469248856177
# 196.	 -0.469374318647
# 197.	 -0.469400469122
# 198.	 -0.469504454177
# 199.	 -0.469527974164

# %% [markdown]
# Now we apply the affine transform to the input CLARITY image and mask

# %%
inImg = imgApplyAffine(inImg, affine, size=refImg.GetSize())
imgShow(inImg, vmax=inThreshold)
inMask = imgApplyAffine(inMask, affine, size=refImg.GetSize(), useNearest=True)

# %% [markdown]
# ## LDDMM registration
# Now we run LDDMM registration. Here we use *imgMetamorphosisComposite*.  Unlike *imgMetamorphosis* introduced in the [2D registration notebook](2D_Registration.ipynb), this function runs LDDMM in multiple steps using the alpha values specified by in *alphaList*. The *field* and *invField* outputs are the composition of all steps.  Once agan we use a Mutual Information cost because the input CLARITY brain and reference ARA average have very differnt intensity profiles.

# %%
inImg_ds = imgResample(inImg, spacing=spacing)
inMask_ds = imgResample(inMask, spacing=spacing, useNearest=True)
(field, invField) = imgMetamorphosisComposite(inImg_ds, refImg_ds, inMask=inMask_ds, alphaList=[0.05, 0.02, 0.01], scaleList = [0.25, 0.5, 1.0], useMI=True, iterations=100, verbose=True)
inImg = imgApplyField(inImg, field, size=refImg.GetSize())
inMask = imgApplyField(inMask, field, size=refImg.GetSize(), useNearest=True)
imgShow(inImg, vmax=inThreshold)
imgShow(inMask)
# Out:
# Step 0: alpha=0.05, beta=0.05, scale=0.25
# 	E, E_velocity, E_rate, E_image (E_image %), LearningRate
# 0.	-1.20274e+10, 134.011, 0, -1.20274e+10 (99.3844%), 6.875000e-05
# 1.	-1.23228e+10, 190.512, 0, -1.23228e+10 (98.9063%), 7.562500e-05
# 2.	-1.23464e+10, 198.501, 0, -1.23464e+10 (98.8682%), 2.079688e-05
# 3.	-1.23888e+10, 200.895, 0, -1.23888e+10 (98.7996%), 5.719141e-06
# 4.	-1.23923e+10, 204.586, 0, -1.23923e+10 (98.794%), 6.291055e-06
# 5.	-1.24548e+10, 209.43, 0, -1.24548e+10 (98.6928%), 6.920160e-06
# 6.	-1.25294e+10, 214.503, 0, -1.25294e+10 (98.5721%), 7.612176e-06
# 7.	-1.25688e+10, 217.2, 0, -1.25688e+10 (98.5083%), 4.186697e-06
# 8.	-1.26058e+10, 218.933, 0, -1.26058e+10 (98.4484%), 4.605367e-06
# E = -1.26058e+10 (98.4484%)
# Length = 24.9487
# Time = 26.7086s (0.445144m)
#
# Step 1: alpha=0.02, beta=0.05, scale=0.5
# 	E, E_velocity, E_rate, E_image (E_image %), LearningRate
# 0.	-9.49975e+09, 92.5333, 0, -9.49975e+09 (97.8611%), 1.100000e-03
# 1.	-1.05493e+10, 208.544, 0, -1.05493e+10 (96.2101%), 1.210000e-03
# 2.	-1.13175e+10, 420.299, 0, -1.13175e+10 (95.0018%), 1.331000e-03
# 3.	-1.17574e+10, 533.233, 0, -1.17574e+10 (94.3097%), 7.320500e-04
# 4.	-1.19428e+10, 651.383, 0, -1.19428e+10 (94.0181%), 8.052550e-04
# 5.	-1.30236e+10, 701.101, 0, -1.30236e+10 (92.3181%), 4.428903e-04
# 6.	-1.35308e+10, 782.859, 0, -1.35308e+10 (91.5202%), 4.871793e-04
# 7.	-1.35742e+10, 831.737, 0, -1.35742e+10 (91.4519%), 2.679486e-04
# 8.	-1.38466e+10, 883.812, 0, -1.38466e+10 (91.0235%), 2.947435e-04
# 9.	-1.38578e+10, 915.161, 0, -1.38578e+10 (91.0059%), 1.621089e-04
# 10.	-1.40272e+10, 945.837, 0, -1.40272e+10 (90.7393%), 1.783198e-04
# 11.	-1.40376e+10, 986.462, 0, -1.40376e+10 (90.7231%), 1.961518e-04
# 12.	-1.43141e+10, 1027.42, 0, -1.43141e+10 (90.2881%), 2.157670e-04
# 13.	-1.43145e+10, 1040.56, 0, -1.43145e+10 (90.2875%), 5.933591e-05
# 14.	-1.43433e+10, 1056.37, 0, -1.43433e+10 (90.2422%), 6.526950e-05
# 15.	-1.4394e+10, 1072.56, 0, -1.4394e+10 (90.1624%), 7.179645e-05
# 16.	-1.44388e+10, 1090.06, 0, -1.44388e+10 (90.092%), 7.897610e-05
# 17.	-1.44902e+10, 1108.69, 0, -1.44902e+10 (90.0111%), 8.687371e-05
# 18.	-1.4543e+10, 1127.34, 0, -1.4543e+10 (89.928%), 9.556108e-05
# 19.	-1.45905e+10, 1148.06, 0, -1.45905e+10 (89.8533%), 1.051172e-04
# 	E, E_velocity, E_rate, E_image (E_image %), LearningRate
# 20.	-1.46198e+10, 1174.07, 0, -1.46198e+10 (89.8072%), 1.156289e-04
# 21.	-1.47025e+10, 1201.36, 0, -1.47025e+10 (89.6771%), 1.271918e-04
# 22.	-1.47222e+10, 1230.65, 0, -1.47222e+10 (89.6462%), 1.399110e-04
# 23.	-1.48156e+10, 1262.94, 0, -1.48157e+10 (89.4991%), 1.539021e-04
# 24.	-1.48359e+10, 1298.88, 0, -1.48359e+10 (89.4672%), 1.692923e-04
# 25.	-1.49564e+10, 1339.99, 0, -1.49564e+10 (89.2777%), 1.862215e-04
# 26.	-1.49607e+10, 1351.79, 0, -1.49607e+10 (89.271%), 5.121091e-05
# 27.	-1.49743e+10, 1365.03, 0, -1.49743e+10 (89.2496%), 5.633201e-05
# 28.	-1.49993e+10, 1379.54, 0, -1.49993e+10 (89.2102%), 6.196521e-05
# 29.	-1.50372e+10, 1395.57, 0, -1.50372e+10 (89.1506%), 6.816173e-05
# 30.	-1.5064e+10, 1412.06, 0, -1.5064e+10 (89.1085%), 7.497790e-05
# 31.	-1.50708e+10, 1416.78, 0, -1.50708e+10 (89.0978%), 2.061892e-05
# 32.	-1.50708e+10, 1417.44, 0, -1.50708e+10 (89.0978%), 2.835102e-06
# 33.	-1.50709e+10, 1417.8, 0, -1.50709e+10 (89.0977%), 1.559306e-06
# 34.	-1.50716e+10, 1418.01, 0, -1.50716e+10 (89.0965%), 8.576183e-07
# 35.	-1.50717e+10, 1418.06, 0, -1.50717e+10 (89.0963%), 2.358450e-07
# 36.	-1.50718e+10, 1418.09, 0, -1.50718e+10 (89.0962%), 1.297148e-07
# 37.	-1.50718e+10, 1418.1, 0, -1.50718e+10 (89.0962%), 1.783578e-08
# 38.	-1.50718e+10, 1418.1, 0, -1.50718e+10 (89.0962%), 9.809679e-09
# 39.	-1.50718e+10, 1418.1, 0, -1.50718e+10 (89.0962%), 5.395324e-09
# 	E, E_velocity, E_rate, E_image (E_image %), LearningRate
# 40.	-1.50718e+10, 1418.1, 0, -1.50718e+10 (89.0962%), 1.483714e-09
# 41.	-1.50718e+10, 1418.1, 0, -1.50718e+10 (89.0962%), 8.160427e-10
# 42.	-1.50718e+10, 1418.1, 0, -1.50718e+10 (89.0962%), 2.244117e-10
# 43.	-1.50718e+10, 1418.1, 0, -1.50718e+10 (89.0962%), 1.234265e-10
# E = -1.50711e+10 (89.0973%)
# Length = 43.6183
# Time = 167.485s (2.79141m)
#
# Step 2: alpha=0.01, beta=0.05, scale=1.0
# 	E, E_velocity, E_rate, E_image (E_image %), LearningRate
# 0.	-1.42271e+10, 2.58645, 0, -1.42271e+10 (99.4168%), 1.100000e-03
# 1.	-1.45018e+10, 4.50389, 0, -1.45018e+10 (98.9355%), 1.210000e-03
# 2.	-1.45558e+10, 5.1992, 0, -1.45558e+10 (98.841%), 3.327500e-04
# 3.	-1.46107e+10, 6.15521, 0, -1.46107e+10 (98.7448%), 3.660250e-04
# 4.	-1.46636e+10, 7.28535, 0, -1.46636e+10 (98.652%), 4.026275e-04
# 5.	-1.46899e+10, 8.71466, 0, -1.46899e+10 (98.606%), 4.428903e-04
# 6.	-1.47009e+10, 10.5593, 0, -1.47009e+10 (98.5868%), 4.871793e-04
# 7.	-1.47893e+10, 12.5564, 0, -1.47893e+10 (98.4318%), 5.358972e-04
# 8.	-1.48896e+10, 14.6043, 0, -1.48896e+10 (98.2562%), 5.894869e-04
# 9.	-1.49127e+10, 17.4152, 0, -1.49127e+10 (98.2157%), 6.484356e-04
# 10.	-1.4921e+10, 20.9222, 0, -1.4921e+10 (98.2012%), 7.132792e-04
# 11.	-1.50083e+10, 22.8294, 0, -1.50083e+10 (98.0482%), 3.923035e-04
# 12.	-1.50895e+10, 24.9825, 0, -1.50895e+10 (97.906%), 4.315339e-04
# 13.	-1.51477e+10, 27.5664, 0, -1.51477e+10 (97.8039%), 4.746873e-04
# 14.	-1.51894e+10, 30.6165, 0, -1.51894e+10 (97.7309%), 5.221560e-04
# 15.	-1.52015e+10, 34.2872, 0, -1.52015e+10 (97.7097%), 5.743716e-04
# 16.	-1.52586e+10, 36.2096, 0, -1.52586e+10 (97.6098%), 3.159044e-04
# 17.	-1.53163e+10, 38.417, 0, -1.53163e+10 (97.5086%), 3.474948e-04
# 18.	-1.53531e+10, 40.8718, 0, -1.53531e+10 (97.4441%), 3.822443e-04
# 19.	-1.53905e+10, 43.7318, 0, -1.53905e+10 (97.3786%), 4.204687e-04
# 	E, E_velocity, E_rate, E_image (E_image %), LearningRate
# 20.	-1.54192e+10, 46.9844, 0, -1.54192e+10 (97.3284%), 4.625156e-04
# 21.	-1.54215e+10, 50.8021, 0, -1.54215e+10 (97.3243%), 5.087672e-04
# 22.	-1.5469e+10, 55.1383, 0, -1.5469e+10 (97.241%), 5.596439e-04
# 23.	-1.55023e+10, 57.5109, 0, -1.55023e+10 (97.1827%), 3.078041e-04
# 24.	-1.55614e+10, 60.2089, 0, -1.55614e+10 (97.0793%), 3.385846e-04
# 25.	-1.55972e+10, 63.2142, 0, -1.55972e+10 (97.0165%), 3.724430e-04
# 26.	-1.56356e+10, 66.6788, 0, -1.56356e+10 (96.9492%), 4.096873e-04
# 27.	-1.56611e+10, 70.5494, 0, -1.56611e+10 (96.9045%), 4.506561e-04
# 28.	-1.56658e+10, 75.1213, 0, -1.56658e+10 (96.8964%), 4.957217e-04
# 29.	-1.57084e+10, 77.5355, 0, -1.57084e+10 (96.8217%), 2.726469e-04
# 30.	-1.57542e+10, 80.3507, 0, -1.57542e+10 (96.7414%), 2.999116e-04
# 31.	-1.57572e+10, 83.434, 0, -1.57572e+10 (96.7363%), 3.299028e-04
# 32.	-1.57735e+10, 86.886, 0, -1.57735e+10 (96.7077%), 3.628930e-04
# 33.	-1.5783e+10, 90.7602, 0, -1.5783e+10 (96.6909%), 3.991823e-04
# 34.	-1.58082e+10, 95.2009, 0, -1.58082e+10 (96.6468%), 4.391006e-04
# 35.	-1.58461e+10, 97.5801, 0, -1.58461e+10 (96.5805%), 2.415053e-04
# 36.	-1.5878e+10, 100.277, 0, -1.5878e+10 (96.5246%), 2.656558e-04
# 37.	-1.59065e+10, 103.246, 0, -1.59065e+10 (96.4747%), 2.922214e-04
# 38.	-1.59275e+10, 106.647, 0, -1.59275e+10 (96.4379%), 3.214436e-04
# 39.	-1.59516e+10, 110.478, 0, -1.59516e+10 (96.3956%), 3.535879e-04
# 	E, E_velocity, E_rate, E_image (E_image %), LearningRate
# 40.	-1.59694e+10, 114.739, 0, -1.59694e+10 (96.3645%), 3.889467e-04
# 41.	-1.59957e+10, 117.076, 0, -1.59957e+10 (96.3184%), 2.139207e-04
# 42.	-1.60182e+10, 119.7, 0, -1.60182e+10 (96.279%), 2.353128e-04
# 43.	-1.60413e+10, 122.58, 0, -1.60413e+10 (96.2385%), 2.588440e-04
# 44.	-1.60579e+10, 125.834, 0, -1.60579e+10 (96.2095%), 2.847285e-04
# 45.	-1.60716e+10, 129.539, 0, -1.60716e+10 (96.1855%), 3.132013e-04
# 46.	-1.60829e+10, 133.578, 0, -1.60829e+10 (96.1656%), 3.445214e-04
# 47.	-1.61076e+10, 135.796, 0, -1.61076e+10 (96.1224%), 1.894868e-04
# 48.	-1.61248e+10, 138.277, 0, -1.61248e+10 (96.0923%), 2.084355e-04
# 49.	-1.61408e+10, 141.007, 0, -1.61408e+10 (96.0642%), 2.292790e-04
# 50.	-1.61556e+10, 144.073, 0, -1.61556e+10 (96.0382%), 2.522069e-04
# 51.	-1.61771e+10, 147.528, 0, -1.61771e+10 (96.0006%), 2.774276e-04
# 52.	-1.61814e+10, 151.278, 0, -1.61814e+10 (95.9931%), 3.051704e-04
# 53.	-1.62052e+10, 153.341, 0, -1.62052e+10 (95.9514%), 1.678437e-04
# 54.	-1.62172e+10, 155.6, 0, -1.62172e+10 (95.9303%), 1.846281e-04
# 55.	-1.62326e+10, 158.112, 0, -1.62326e+10 (95.9034%), 2.030909e-04
# 56.	-1.62458e+10, 160.884, 0, -1.62458e+10 (95.8803%), 2.234000e-04
# 57.	-1.62641e+10, 164.002, 0, -1.62641e+10 (95.8481%), 2.457400e-04
# 58.	-1.62664e+10, 167.359, 0, -1.62664e+10 (95.8441%), 2.703140e-04
# 59.	-1.62888e+10, 169.231, 0, -1.62888e+10 (95.8048%), 1.486727e-04
# 	E, E_velocity, E_rate, E_image (E_image %), LearningRate
# 60.	-1.62976e+10, 171.261, 0, -1.62976e+10 (95.7895%), 1.635399e-04
# 61.	-1.63098e+10, 173.532, 0, -1.63098e+10 (95.7681%), 1.798939e-04
# 62.	-1.63218e+10, 176.052, 0, -1.63218e+10 (95.7471%), 1.978833e-04
# 63.	-1.63355e+10, 178.911, 0, -1.63355e+10 (95.7231%), 2.176717e-04
# 64.	-1.63372e+10, 181.957, 0, -1.63372e+10 (95.7201%), 2.394388e-04
# 65.	-1.63436e+10, 185.434, 0, -1.63436e+10 (95.7089%), 2.633827e-04
# 66.	-1.63575e+10, 189.251, 0, -1.63575e+10 (95.6846%), 2.897210e-04
# 67.	-1.63729e+10, 193.518, 0, -1.63729e+10 (95.6576%), 3.186931e-04
# 68.	-1.63987e+10, 195.857, 0, -1.63987e+10 (95.6124%), 1.752812e-04
# 69.	-1.64064e+10, 198.364, 0, -1.64064e+10 (95.5988%), 1.928093e-04
# 70.	-1.64261e+10, 201.232, 0, -1.64261e+10 (95.5644%), 2.120902e-04
# 71.	-1.64281e+10, 202.779, 0, -1.64281e+10 (95.5608%), 1.166496e-04
# 72.	-1.64366e+10, 204.519, 0, -1.64366e+10 (95.546%), 1.283146e-04
# 73.	-1.64432e+10, 206.431, 0, -1.64432e+10 (95.5345%), 1.411461e-04
# 74.	-1.64521e+10, 208.569, 0, -1.64521e+10 (95.5189%), 1.552607e-04
# 75.	-1.64599e+10, 210.91, 0, -1.64599e+10 (95.5052%), 1.707867e-04
# 76.	-1.64708e+10, 213.554, 0, -1.64708e+10 (95.486%), 1.878654e-04
# 77.	-1.64734e+10, 216.392, 0, -1.64734e+10 (95.4814%), 2.066519e-04
# 78.	-1.64828e+10, 219.632, 0, -1.64828e+10 (95.4651%), 2.273171e-04
# 79.	-1.64896e+10, 223.161, 0, -1.64896e+10 (95.4532%), 2.500489e-04
# 	E, E_velocity, E_rate, E_image (E_image %), LearningRate
# 80.	-1.65023e+10, 227.178, 0, -1.65023e+10 (95.4309%), 2.750537e-04
# 81.	-1.65083e+10, 231.523, 0, -1.65083e+10 (95.4203%), 3.025591e-04
# 82.	-1.65162e+10, 236.465, 0, -1.65162e+10 (95.4065%), 3.328150e-04
# 83.	-1.65263e+10, 241.832, 0, -1.65263e+10 (95.3889%), 3.660965e-04
# 84.	-1.65299e+10, 247.461, 0, -1.65299e+10 (95.3825%), 4.027062e-04
# 85.	-1.65917e+10, 250.663, 0, -1.65917e+10 (95.2743%), 2.214884e-04
# 86.	-1.66005e+10, 254.075, 0, -1.66005e+10 (95.2589%), 2.436372e-04
# 87.	-1.66239e+10, 257.924, 0, -1.66239e+10 (95.2179%), 2.680010e-04
# 88.	-1.66293e+10, 260.052, 0, -1.66293e+10 (95.2083%), 1.474005e-04
# 89.	-1.66409e+10, 262.453, 0, -1.66409e+10 (95.1881%), 1.621406e-04
# 90.	-1.66449e+10, 265.048, 0, -1.66449e+10 (95.1811%), 1.783546e-04
# 91.	-1.66561e+10, 268.037, 0, -1.66561e+10 (95.1615%), 1.961901e-04
# 92.	-1.66623e+10, 269.603, 0, -1.66623e+10 (95.1506%), 1.079046e-04
# 93.	-1.6667e+10, 271.351, 0, -1.6667e+10 (95.1424%), 1.186950e-04
# 94.	-1.66736e+10, 273.318, 0, -1.66736e+10 (95.1309%), 1.305645e-04
# 95.	-1.66796e+10, 275.466, 0, -1.66796e+10 (95.1202%), 1.436210e-04
# 96.	-1.66882e+10, 277.896, 0, -1.66882e+10 (95.1052%), 1.579831e-04
# 97.	-1.66907e+10, 280.495, 0, -1.66907e+10 (95.1008%), 1.737814e-04
# 98.	-1.66982e+10, 283.452, 0, -1.66982e+10 (95.0877%), 1.911595e-04
# 99.	-1.67018e+10, 286.583, 0, -1.67018e+10 (95.0813%), 2.102755e-04
# E = -1.67018e+10 (95.0813%)
# Length = 18.219
# Time = 1492.68s (24.8781m)

# %% [markdown]
# ## Evaluating the registration
# ### Evaluation using checker board
# We can evaluate the registration by generating a checkerboard of the deformed CLARITY and ARA.  In this method the input image is placed on the black squares of the metaphorical checkerboard while the reference image is placed on the red squares.  Idealy anatomical sturctures should line up across squares.

# %%
imgShow(imgChecker(inImg, refImg, useHM=False), vmax=refThreshold, numSlices=1)

# %% [markdown]
# ## Uploading Results
#
# ### Uploading deformed CLARITY image
# We can now upload the ARA-aligned CLARITY brain back into ndstore.

# %%
token = inToken+"_to_ara3"
imgUpload(inImg, token)

# %% [markdown]
# ### Uploading deformed ARA annotations

# %% [markdown]
# To save memory we clear the reference image since it's no longer needed.

# %%
refImg = None

# %% [markdown]
# Now we download the ARA annotations

# %%
refAnnoImg = imgDownload(refToken, channel="annotation")

# %%
spacing_ds = invField.GetSpacing()
size_ds = np.ceil(np.array(refAnnoImg.GetSize())*np.array(refAnnoImg.GetSpacing())/np.array(spacing_ds))
size_ds = list(size_ds.astype(int))

# %% [markdown]
# Before we can overlay the ARA annotations on the downloaded image we must transfom them to its space. Fortunatly this can be done since all spatial transforms in this tutorial are invertable.  First we construct an inverse displacement field which transforms the annotations from the ARA space to the space before registration.

# %%
invAffine = affineInverse(affine)
invAffineField = affineToField(invAffine, size_ds, spacing_ds)
invField2 = fieldApplyField(invAffineField, invField)
inAnnoImg = imgApplyField(refAnnoImg, invField2,useNearest=True, size=inImgSize_reorient, spacing=inImgSpacing_reorient)
inAnnoThreshold = imgPercentile(inAnnoImg,0.99)
imgShow(inAnnoImg, vmax=inAnnoThreshold)

# %% [markdown]
# Were not done yet.  We still need to reorient these annotations from **RSA** to **RPS**

# %%
inAnnoImg = imgReorient(inAnnoImg, refOrient, inOrient)
imgShow(inAnnoImg, vmax=inAnnoThreshold)

# %% [markdown]
# We can upload these annotations at the lowest possible resolution.

# %%
outToken = "ara3_to_152DLS_tail"
outChannel = "annotation_draft"
imgUpload(inAnnoImg, outToken, outChannel, resolution=5)
